# %%
# %load_ext autoreload
# %autoreload 2
# %cd /data1/guming/projects/graph_datasets
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /data1/guming/projects/graph_datasets

# %%
from graph_datasets.utils.plt import draw_chart

draw_chart(
    ys=[[6,2,8],[5,2,7], [6,3,8]],
    lbls=['a','b', 'c'],
    xs=[[2,5,8],[2,5,8],[2.25,5.25,8.25]],
    xmode='d',
    types=['line','bar', 'bar'],
    bar_width=0.25,
    xlim=(0,10),
)
